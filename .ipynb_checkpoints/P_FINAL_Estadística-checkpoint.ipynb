# %% [markdown]
# # Desarrollo de proyecto final de estadística
# ### Integrantes:
# ## Coronado, Arantxa. 2-752-1519
# ## Hernández, José. 8-1002-2448
# ## Lucero, Pedro. 8-973-1067
# ## Valdés, Andrés. 6-726-1938

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Capturamos los datos que usaremos: México y El Salvador

# %%
mex_names = ['MEXICO_2018.csv', 'MEXICO_2019.csv', 'MEXICO_2020.csv', 'MEXICO_2021.csv', 'MEXICO_2022.csv', 'MEXICO_2023.csv']
raw_mex = [pd.read_csv("DATA/" + name, encoding='latin-1') for name in mex_names]
# raw_mex da index 0 → 5, años 2018 → 2023

slv_name = "ELSALVADOR_2020-2024.xlsx"
slv_yrs = ["2020", "2021", "2022", "2023", "2024"]
raw_slv = [pd.read_excel("DATA/" + slv_name, sheet_name=year) for year in slv_yrs]
# raw_mex da index 0 → 4, años 2020 → 2024

# %% [markdown]
# # Datos:
# ## Estos datos provienen de fuentes oficiales de datos abiertos de los gobiernos de México y El Salvador.
# ### Para los archivos de México:
# #### NIVEL: Que nivel educativo se tabuló (e.g. nivel medio superior)
# #### UNIDAD ACADÉMICA: Nombre del plantel educativo (e.g. CECyT 2 "Miguel Bernard Perales")
# #### PROGRAMA: El nombre del programa académico (e.g. Ing. Eléctrica)
# #### MODALIDAD: (no usado) modalidad del programa (e.g. escolarizada)
# #### HOMBRES: Egresados hombres
# #### MUJERES: Egresadas mujeres
#
# ### Para los archivos de El Salvador:
# #### CARRERA: El nombre de la carrera (e.g. Ing. Eléctrica)
# #### MASCULINO: Egresados hombres
# #### FEMENINO: Egresadas mujeres
# #### TOTALES: Egresados totales

# %% [markdown]
# ## Retiramos los datos que no se usarán en absoluto:
# ### Estudiantes de preparatoria

# %%
print(raw_mex[0]["NIVEL EDUCATIVO"].unique())
# Nos interesa revisar solamente estudiantes de nivel superior y prosgrado
# Out:
# ['Nivel Medio Superior' 'Nivel Superior' 'Nivel Posgrado']

# %% [markdown]
# # Limpiamos los datos: México
# ## Ajustamos a nivel de tablas

# %%
# Esta funcion cambia una cadena por otra en toda una columna
# Se usó para corregir tildes mal decodificadas
# Y para estandarizar nombres
def reemplazar_cadenas(s, reemplazos):
    for viejo, nuevo in reemplazos.items():
        s = s.replace(viejo, nuevo)
    return s

# %%
# Tomamos notación iloc porque la col. del último archivo se llama "NIVEL" y no "NIVEL EDUCATIVO"
clean_mex = [tabla.loc[tabla.iloc[:, 0] != "Nivel Medio Superior"] for tabla in raw_mex]

# Nos interesan solo las columnas de nivel, carrera, H y M
clean_mex[:5] = [tabla.iloc[:, [2, 4, 5]] for tabla in clean_mex[:5]]
clean_mex[5] = clean_mex[5].iloc[:, [2, 3, 4]] # Esta es diferente porque 2023 tiene una col. menos

# Estandarizamos los nombres de las columnas
for i in range(len(clean_mex)):
    clean_mex[i].columns = ['CARRERA', 'HOMBRES', 'MUJERES']

# Debemos corregir un mal formato de tildes en los datos de 2022
r_tildes = {'\x87': 'á', '\x8e': 'é', '\x92': 'í', '\x97': 'ó', '\x9c': 'ú'}

clean_mex[4]["CARRERA"] = clean_mex[4]["CARRERA"].apply(lambda x: reemplazar_cadenas(x, r_tildes))

# %% [markdown]
# ## Estandarizamos nombres
# ### e.g. "Ingeniería Eléctrica" → "Ing. Electrica"

# %%
r_nombres = {"Ingeniería": "Ing.", "á": "a", "é": "e", "í": "i", "ó": "o", "ú": "u"}
# Quitamos las tildes al ser inconsistentes por naturaleza, e.g. "Mécanica"
clean_mex[4].loc[clean_mex[4]["CARRERA"].str.contains("Mécanica")]
# Out:
#                                         CARRERA  HOMBRES  MUJERES
# 402  Maestría en Ciencias en Mécanica de suelos        0        0

# %%
for i in range(len(clean_mex)):
    clean_mex[i]["CARRERA"] = clean_mex[i]["CARRERA"].apply(lambda x: reemplazar_cadenas(x, r_nombres))
    clean_mex[i]["TOTAL"] = clean_mex[i]["HOMBRES"] + clean_mex[i]["MUJERES"]

# %% [markdown]
# ## Datos limpios: México

# %%
clean_mex[0]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 101                                     Ing. Electrica      270       25
# 102               Ing. en Comunicaciones y Electronica      523      150
# 103                   Ing. en Control y Automatizacion      295       42
# 104                      Ing. en Sistemas Automotrices       10        0
# 105               Ing. en Comunicaciones y Electronica      155       19
# ..                                                 ...      ...      ...
# 352  Especialidad en Gestion Estrategica de la Inno...       11        3
# 353  Maestria en Ciencias en Metodologia de la Ciencia       11        7
# 354  Maestria en Politica y Gestion del Cambio Tecn...        3       13
# 355           Maestria en Economia y Gestion Municipal       12       12
# 356  Maestria en Docencia Cientifica y Tecnologica ...        7       18
#
#      TOTAL
# 101    295
# 102    673
# 103    337
# 104     10
# 105    174
# ..     ...
# ...

# %%
clean_mex[1]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 102                                     Ing. Electrica      224       17
# 103               Ing. en Comunicaciones y Electronica      518      104
# 104                   Ing. en Control y Automatizacion      320       52
# 105                      Ing. en Sistemas Automotrices       21        0
# 106               Ing. en Comunicaciones y Electronica      200       45
# ..                                                 ...      ...      ...
# 359  Especialidad en Gestion Estrategica de la Inno...        3        4
# 360  Maestria en Ciencias en Metodologia de la Ciencia       13        9
# 361      Maestria en Docencia Cientifica y Tecnologica        6       19
# 362           Maestria en Economia y Gestion Municipal       11       10
# 363  Maestria en Politica y Gestion del Cambio Tecn...        4       13
#
#      TOTAL
# 102    241
# 103    622
# 104    372
# 105     21
# 106    245
# ..     ...
# ...

# %%
clean_mex[2]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 92                                      Ing. Electrica    223.0     26.0
# 93                Ing. en Comunicaciones y Electronica    485.0    135.0
# 94                    Ing. en Control y Automatizacion     14.0      0.0
# 95                       Ing. en Sistemas Automotrices    277.0     46.0
# 96                Ing. en Comunicaciones y Electronica    153.0     27.0
# ..                                                 ...      ...      ...
# 317  Especialidad en Gestion Estrategica de la Inno...      8.0      6.0
# 318  Maestria en Ciencias en Metodologia de la Ciencia     15.0     16.0
# 319      Maestria en Docencia Cientifica y Tecnologica     13.0     30.0
# 320           Maestria en Economia y Gestion Municipal     19.0     19.0
# 321  Maestria en Politica y Gestion del Cambio Tecn...     12.0     11.0
#
#      TOTAL
# 92   249.0
# 93   620.0
# 94    14.0
# 95   323.0
# 96   180.0
# ..     ...
# ...

# %%
clean_mex[3]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 93                    Ing. en Control y Automatizacion      278       61
# 94                       Ing. en Sistemas Automotrices       60        5
# 95                Ing. en Comunicaciones y Electronica      582      132
# 96                                      Ing. Electrica      229       25
# 97                                 Ing. en Computacion      145       30
# ..                                                 ...      ...      ...
# 322  Especialidad en Gestion Estrategica de la Inno...        1        2
# 323      Maestria en Docencia Cientifica y Tecnologica        5       25
# 324  Maestria en Politica y Gestion del Cambio Tecn...        8        1
# 325           Maestria en Economia y Gestion Municipal       10        2
# 326  Maestria en Ciencias en Metodologia de la Ciencia        5        8
#
#      TOTAL
# 93     339
# 94      65
# 95     714
# 96     254
# 97     175
# ..     ...
# ...

# %%
clean_mex[4]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 141                                      Ing. Mecanica      392       81
# 142                      Ing. en Sistemas Automotrices      118        4
# 143                        Ing. en Robotica Industrial      216       32
# 144                                Ing. en Computacion      182       43
# 145                                      Ing. Mecanica      257       44
# ..                                                 ...      ...      ...
# 507               Maestria en Biotecnologia Productiva        0        0
# 508                                 Curso propedeutico        0        0
# 509                Maestria en Ciencias en Bioprocesos        4        4
# 510               Doctorado en Ciencias en Bioprocesos        0        3
# 511  Especialidad de Ing. para el Desarrollo de Sis...        5        2
#
#      TOTAL
# 141    473
# 142    122
# 143    248
# 144    225
# 145    301
# ..     ...
# ...

# %%
clean_mex[4]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 141                                      Ing. Mecanica      392       81
# 142                      Ing. en Sistemas Automotrices      118        4
# 143                        Ing. en Robotica Industrial      216       32
# 144                                Ing. en Computacion      182       43
# 145                                      Ing. Mecanica      257       44
# ..                                                 ...      ...      ...
# 507               Maestria en Biotecnologia Productiva        0        0
# 508                                 Curso propedeutico        0        0
# 509                Maestria en Ciencias en Bioprocesos        4        4
# 510               Doctorado en Ciencias en Bioprocesos        0        3
# 511  Especialidad de Ing. para el Desarrollo de Sis...        5        2
#
#      TOTAL
# 141    473
# 142    122
# 143    248
# 144    225
# 145    301
# ..     ...
# ...

# %%
clean_mex[5]
# Out:
#                                                CARRERA  HOMBRES  MUJERES  \
# 117                                      Ing. Mecanica      378       70
# 118                        Ing. en Robotica Industrial      194       42
# 119                      Ing. en Sistemas Automotrices      136       10
# 120                                      Ing. Mecanica      285       45
# 121                                Ing. en Computacion      167       49
# ..                                                 ...      ...      ...
# 418                Maestria en Ciencias en Bioprocesos        3        4
# 419  Doctorado en Nanociencias y Micro - Nanotecnol...        1        0
# 420              Doctorado en Biotecnologia Productiva        0        0
# 421               Maestria en Biotecnologia Productiva        0        0
# 422  Especialidad en Ing. para el Desarrollo de Sis...        5        0
#
#      TOTAL
# 117    448
# 118    236
# 119    146
# 120    330
# 121    216
# ..     ...
# ...

# %% [markdown]
# # Limpiamos los datos: El Salvador
# ## Creamos tablas limpias sin necesidad de mucha depuración

# %%
clean_slv = [tabla[2:] for tabla in raw_slv]
for i in range(len(raw_slv)):
    clean_slv[i].columns = ["CARRERA", "HOMBRES", "MUJERES", "TOTAL"]
    clean_slv[i] = clean_slv[i].loc[clean_slv[i]["HOMBRES"].notna()] # Quitamos filas donde indican la facultad
    clean_slv[i] = clean_slv[i].loc[clean_slv[i]["CARRERA"].str.contains("Facultad") == False] # Quitamos filas donde indican total x facultad
    clean_slv[i]["CARRERA"] = clean_slv[i]["CARRERA"].apply(lambda x: reemplazar_cadenas(x, r_nombres)) # Formateamos carreras

# %% [markdown]
# ## Datos limpios: El Salvador

# %%
clean_slv[0]
# Out:
#                                                CARRERA HOMBRES MUJERES TOTAL
# 2                Doctorado en Medicina (D10101 - 1992)     132     153   285
# 3    Especialidad Medica en Cirugia General (E10101...       1       0     1
# 4    Especialidad Medica en Cirugia General (E10101...      17       6    23
# 5    Especialidad Medica en Ginecologia y Obstetric...       0       1     1
# 6    Especialidad Medica en Ginecologia y Obstetric...       4      12    16
# ..                                                 ...     ...     ...   ...
# 188  Maestria en Traduccion Ingles Español - Españo...       0       1     1
# 189  Maestria en Estudios de Cultura Centroamerican...       2       4     6
# 190  Profesorado en Educacion Basica para Primero y...       0       1     1
# 191  Profesorado en Lenguaje y Literatura para Terc...       1       1     2
# 192         Tecnico en Bibliotecologia (T10454 - 2012)       0       3     3
#
# [169 rows x 4 columns]

# %%
clean_slv[1]
# Out:
#                                                CARRERA HOMBRES MUJERES TOTAL
# 2                Doctorado en Medicina (D10101 - 1992)     109     123   232
# 3    Especialidad Medica en Cirugia General (E10101...       1       0     1
# 4    Especialidad Medica en Ginecologia y Obstetric...       1      15    16
# 5    Especialidad Medica en Medicina Interna (E1010...       4       0     4
# 6    Especialidad Medica en Medicina Interna (E1010...       9      12    21
# ..                                                 ...     ...     ...   ...
# 221  Profesorado en Lenguaje y Literatura para Terc...       3      14    17
# 222  Profesorado en Idioma Ingles para Tercer Ciclo...       0       1     1
# 223         Tecnico en Bibliotecologia (T10454 - 2012)       2      12    14
# 224  Maestria en Formacion para la Docencia Univers...       2       6     8
# 225  Licenciatura en Ciencias de la Educacion (L104...       0       1     1
#
# [202 rows x 4 columns]

# %%
clean_slv[2]
# Out:
#                                                CARRERA HOMBRES MUJERES TOTAL
# 2                Doctorado en Medicina (D10101 - 1992)     106     151   257
# 3    Especialidad Medica en Cirugia General (E10101...       2       1     3
# 4    Especialidad Medica en Cirugia General (E10101...      12       6    18
# 5    Especialidad Medica en Ginecologia y Obstetric...       4      15    19
# 6    Especialidad Medica en Medicina Interna (E1010...       2       0     2
# ..                                                 ...     ...     ...   ...
# 239  Profesorado en Educacion Parvularia (P10401 - ...       0       1     1
# 240  Profesorado en Lenguaje y Literatura para Terc...       2      10    12
# 241  Profesorado en Idioma Ingles para Tercer Ciclo...       2       0     2
# 242         Tecnico en Bibliotecologia (T10454 - 2012)       4      16    20
# 243  Maestria en Formacion para la Docencia Univers...       7       7    14
#
# [220 rows x 4 columns]

# %%
clean_slv[3]
# Out:
#                                                CARRERA HOMBRES MUJERES TOTAL
# 2                Doctorado en Medicina (D10101 - 1992)     115     133   248
# 3    Especialidad Medica en Cirugia General (E10101...       1       0     1
# 4    Especialidad Medica en Cirugia General (E10101...       7       5    12
# 5    Especialidad Medica en Ginecologia y Obstetric...       2      14    16
# 6    Especialidad Medica en Medicina Interna (E1010...       0       2     2
# ..                                                 ...     ...     ...   ...
# 245  Maestria en Estudios de Cultura Centroamerican...       0       1     1
# 246  Profesorado en Lenguaje y Literatura para Terc...       2      11    13
# 247         Tecnico en Bibliotecologia (T10454 - 2012)       3       6     9
# 248  Maestria en Formacion para la Docencia Univers...       2       2     4
# 249        Licenciatura en Psicologia (L10407 - 1977c)       0       1     1
#
# [226 rows x 4 columns]

# %%
clean_slv[4]
# Out:
#                                                CARRERA HOMBRES MUJERES TOTAL
# 2                Doctorado en Medicina (D10101 - 1992)     104     152   256
# 3    Especialidad Medica en Cirugia General (E10101...       2       0     2
# 4    Especialidad Medica en Ginecologia y Obstetric...       0       1     1
# 5    Especialidad Medica en Ginecologia y Obstetric...       2      16    18
# 6    Especialidad Medica en Medicina Interna (E1010...       4       4     8
# ..                                                 ...     ...     ...   ...
# 209  Profesorado en Educacion Fisica y Deportes (P1...       1       0     1
# 210  Profesorado en Lenguaje y Literatura para Terc...       0       2     2
# 211         Licenciatura en Sociologia (L10406 - 1995)       1       0     1
# 212  Maestria en Formacion para la Docencia Univers...       2       2     4
# 213  Licenciatura en Educacion, Especialidad Admini...       3       4     7
#
# [190 rows x 4 columns]

# %% [markdown]
# # Moda de carrera (top 5) México

# %%
max_y_value = 870

# grid 2x2
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, year in enumerate([str(yr) for yr in range(2018, 2024)]):
    current = clean_mex[i].sort_values("TOTAL", ascending=False).head(5).set_index("CARRERA")["TOTAL"]
#     current
    
    # Plotting
    ax = current.plot(kind='bar', ax=axes[i], color="green")
    
    ax.set_title(f'Moda de carrera México {year}')
    ax.set_xlabel("Carrera")
    ax.set_ylabel("Egresados")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=-20, ha='left')
    ax.set_ylim(0, max_y_value)

plt.subplots_adjust(hspace=0.7)

plt.show()

# %% [markdown]
# # Moda de carrera (top 5) El Salvador

# %%
max_y_value = 600

# grid 2x2
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, year in enumerate([str(yr) for yr in range(2020, 2025)]):
    current = clean_slv[i].sort_values("TOTAL", ascending=False).head(5).set_index("CARRERA")["TOTAL"]
#     current
    
    # Plotting
    ax = current.plot(kind='bar', ax=axes[i], color="blue")
    
    ax.set_title(f'Moda de carrera El Salvador {year}')
    ax.set_xlabel("Carrera")
    ax.set_ylabel("Egresados")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=-20, ha='left')
    ax.set_ylim(0, max_y_value)

plt.subplots_adjust(hspace=1.5)
fig.delaxes(axes[-1])
plt.show()

# %% [raw]
# Areas que SLV no provee:
# Ing. Electronica
# Ing. Metalurgia/Materiales
# Ing. Mecatronica
# Ing. Comunicaciones
# Ing. en Computacion
# Ing. en Sistemas Computacionales
#
# Maestrías/Doctorados en estas áreas
#
# Areas a usar: MEX/SLV:
# Ing. Electrica/Ing. Electrica
# Ing. Mecanica/Ing. Mecanica
# Ing. Industrial/Ing. Industrial
# Ing. en Informatica/Ing. de Sistemas Informaticos
#
# Física?

# %%
areas_estudio = ["Ing. Electrica",
                 "Ing. Mecanica",
                 "Ing. Industrial"]
# Luego añadimos manualmente Ing. en Informatica/Ing. de Sistemas Informaticos

country_year = {}
country_year["MEX2018"] = clean_mex[0]
country_year["MEX2019"] = clean_mex[1]
country_year["MEX2020"] = clean_mex[2]
country_year["MEX2021"] = clean_mex[3]
country_year["MEX2022"] = clean_mex[4]
country_year["MEX2023"] = clean_mex[5]

country_year["SLV2020"] = clean_slv[0]
country_year["SLV2021"] = clean_slv[1]
country_year["SLV2022"] = clean_slv[2]
country_year["SLV2023"] = clean_slv[3]
country_year["SLV2024"] = clean_slv[4]

encontrados = [0]*len(areas_estudio)

for index, area in enumerate(areas_estudio):
    for key, cwd in country_year.items():
        if len(cwd.loc[cwd["CARRERA"].str.contains(area)]) > 0:
            encontrados[index] += 1
        else:
            print(areas_estudio[index], "no está en", key)
    
encontrados
# Out:
# [11, 11, 11]

# %%
comp_paises = pd.DataFrame()
comp_paises.index = ["Ing. Electrica",
                     "Ing. Mecanica",
                     "Ing. Industrial",
                     "Ing. Informatica"]

total_por_sexo = pd.DataFrame()
total_por_sexo.index = ["México", "El Salvador"]

cp_columns = ["MEX2018", "MEX2019", "MEX2020", "MEX2021", "MEX2022", "MEX2023",
              "SLV2020", "SLV2021", "SLV2022", "SLV2023", "SLV2024"]

total_h_mex = 0
total_h_slv = 0
total_m_mex = 0
total_m_slv = 0
for column in cp_columns:
    total = []
    cwd = country_year[column]
    for area in areas_estudio:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains(area)]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains(area)]["MUJERES"])
        total.append(int(h_v + m_v))
        if "MEX" in column:
            total_h_mex += h_v
            total_m_mex += m_v
        if "SLV" in column:
            total_h_slv += h_v
            total_m_slv += m_v
    
    if "MEX" in column:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. en Informatica")]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. en Informatica")]["MUJERES"])
        total.append(int(h_v + m_v))
        total_h_mex += h_v
        total_m_mex += m_v
    if "SLV" in column:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. de Sistemas Informaticos")]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. de Sistemas Informaticos")]["MUJERES"])
        total.append(int(h_v + m_v))
        total_h_slv += h_v
        total_m_slv += m_v

    comp_paises[column] = total
    total_por_sexo["Hombres"] = [int(total_h_mex), int(total_h_slv)]
    total_por_sexo["Mujeres"] = [int(total_m_mex), int(total_m_slv)]

# %%
comp_paises
# Out:
#                   MEX2018  MEX2019  MEX2020  MEX2021  MEX2022  MEX2023  \
# Ing. Electrica        310      257      278      267      297      327
# Ing. Mecanica         767      551      715      770      870      897
# Ing. Industrial       568      130      437      542      527      654
# Ing. Informatica      205      170      152      214      208      256
#
#                   SLV2020  SLV2021  SLV2022  SLV2023  SLV2024
# Ing. Electrica         21       32       79       54       28
# Ing. Mecanica           9       14       36       31       11
# Ing. Industrial        53      145      167      101       33
# Ing. Informatica      100      217      137      161      114

# %% [markdown]
# # Promedio de graduados por año

# %%
max_y_value = 600
fig, axes = plt.subplots(1, 2, figsize=(20, 9))

mex_avgs = [table["TOTAL"].mean() for table in clean_mex]
mex_years = [str(yr) for yr in range(2018, 2024)]

slv_avgs = [table["TOTAL"].mean() for table in clean_slv]
slv_years = [str(yr) for yr in range(2020, 2025)]

axes[0].plot(mex_years, mex_avgs, marker='o', linestyle='--', c="green")
axes[0].plot(slv_years, slv_avgs, marker='o', linestyle='--', c="blue")
axes[0].set_title("Promedio de graduados por carrera general")
axes[0].set_xlabel("Año")
axes[0].set_ylabel("Promedio")
axes[0].legend(["México", "El Salvador"])
axes[0].set_ylim(0, max_y_value)

am_avg = [comp_paises[name].mean() for name in comp_paises.columns if "MEX" in name]
as_avg = [comp_paises[name].mean() for name in comp_paises.columns if "SLV" in name]

axes[1].plot(mex_years, am_avg, marker='o', linestyle='--', c="green")
axes[1].plot(slv_years, as_avg, marker='o', linestyle='--', c="blue")
axes[1].set_title("Promedio de graduados por carrera analizada")
axes[1].set_xlabel("Año")
axes[1].set_ylabel("Promedio")
axes[1].legend(["México", "El Salvador"])
axes[1].set_ylim(0, max_y_value)

plt.show()

# %% [markdown]
# # Varianza en graduados por año

# %%
max_y_value = 100000
fig, axes = plt.subplots(1, 2, figsize=(20, 9))

mex_var = [table["TOTAL"].var() for table in clean_mex]
mex_years = [str(yr) for yr in range(2018, 2024)]

slv_var = [table["TOTAL"].var() for table in clean_slv]
slv_years = [str(yr) for yr in range(2020, 2025)]

axes[0].plot(mex_years, mex_var, marker='o', linestyle='--', c="green")
axes[0].plot(slv_years, slv_var, marker='o', linestyle='--', c="blue")
axes[0].set_title("Varianza de egresados de datos generales")
axes[0].set_xlabel("Año")
axes[0].set_ylabel("Varianza")
axes[0].legend(["México", "El Salvador"])
axes[0].set_ylim(0, max_y_value)

am_var = [comp_paises[name].var() for name in comp_paises.columns if "MEX" in name]
as_var = [comp_paises[name].var() for name in comp_paises.columns if "SLV" in name]

axes[1].plot(mex_years, am_var, marker='o', linestyle='--', c="green")
axes[1].plot(slv_years, as_var, marker='o', linestyle='--', c="blue")
axes[1].set_title("Varianza de egresados de datos analizados")
axes[1].set_xlabel("Año")
axes[1].set_ylabel("Vatianza")
axes[1].legend(["México", "El Salvador"])
axes[1].set_ylim(0, max_y_value)

plt.show()

# %% [markdown]
# ### Para generales:
# ##### Se puede apreciar que la varianza es muy alta, esto es porque existen muchas carreras con pocos a nulos egresados
# ### Para analizados:
# #### Estos datos llevan mucha más varianza por consecuencia de solo estar considerando 4 carreras

# %%
total_por_sexo
# Out:
#              Hombres  Mujeres
# México          8204     2165
# El Salvador     1191      352

# %% [markdown]
# # Comparaciones sobre los años en común

# %%
max_y_value = 5900

# Plotting
ax = total_por_sexo.plot(kind='bar', figsize=(8, 4), color=["green", "blue"])

ax.set_title('Egresados hombres y mujeres totales por país, 2020-2023')
ax.set_xlabel("País")
ax.set_ylabel("Egresados")
ax.legend(["Hombres", "Mujeres"])
ax.set_ylim(0, max_y_value)

plt.show()

# %%
max_y_value = 910

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

for i, year in enumerate(["2020", "2021", "2022", "2023"]):
    comp_year = comp_paises.filter(regex=f'{year}$')
    
    # Plotting
    ax = comp_year.plot(kind='bar', ax=axes[i], color=["green", "blue"])
    
    ax.set_title(f'Egresados México vs. El Salvador por carrera ({year})')
    ax.set_xlabel("Carrera")
    ax.set_ylabel("Egresados")
    ax.legend(["México", "El Salvador"])
    ax.set_ylim(0, max_y_value)

plt.tight_layout()

# Show the plot
plt.show()

# %%
mexico_x_anho = pd.DataFrame()
mexico_x_anho.index = ["Ing. Electrica",
                        "Ing. Mecanica",
                        "Ing. Industrial",
                        "Ing. Informatica"]

mxa_cols = ["MEX2018", "MEX2019", "MEX2020", "MEX2021", "MEX2022", "MEX2023"]

for column in mxa_cols:
    total = []
    hombre = []
    mujer = []
    cwd = country_year[column]
    for area in areas_estudio:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains(area)]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains(area)]["MUJERES"])
        hombre.append(int(h_v))
        mujer.append(int(m_v))
        total.append(int(h_v + m_v))
    
    if "MEX" in column:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. en Informatica")]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. en Informatica")]["MUJERES"])
        hombre.append(int(h_v))
        mujer.append(int(m_v))
        total.append(int(h_v + m_v))

    mexico_x_anho[int(column[3:])] = total

# %%
mexico_x_anho
# Out:
#                   2018  2019  2020  2021  2022  2023
# Ing. Electrica     310   257   278   267   297   327
# Ing. Mecanica      767   551   715   770   870   897
# Ing. Industrial    568   130   437   542   527   654
# Ing. Informatica   205   170   152   214   208   256

# %% [markdown]
# # Egresados por año

# %%
max_y_mex = 1120

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(11, 8))
fig.suptitle('Egresados por año en México de 2018 a 2023', fontsize=20)
axes = axes.flatten()


for i, carrera in enumerate(mexico_x_anho.index):
    mex_carrera = mexico_x_anho.loc[carrera]
    
    # Plotting
    axes[i].bar(mexico_x_anho.columns, mex_carrera, color="green", label='Bar')
    
    axes[i].set_title(f'{carrera}')
    axes[i].set_xlabel("Año")
    axes[i].set_ylabel("Egresados")
    axes[i].set_ylim(0, max_y_mex)

plt.tight_layout()

# Show the plot
plt.show()

# %%
salvador_x_anho = pd.DataFrame()
salvador_x_anho.index = ["Ing. Electrica",
                        "Ing. Mecanica",
                        "Ing. Industrial",
                        "Ing. Informatica"]

sxa_cols = ["SLV2020", "SLV2021", "SLV2022", "SLV2023", "SLV2024"]

for column in sxa_cols:
    total = []
    hombre = []
    mujer = []
    cwd = country_year[column]
    for area in areas_estudio:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains(area)]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains(area)]["MUJERES"])
        hombre.append(int(h_v))
        mujer.append(int(m_v))
        total.append(int(h_v + m_v))
    
    if "SLV" in column:
        h_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. de Sistemas Informaticos")]["HOMBRES"])
        m_v = sum(cwd.loc[cwd["CARRERA"].str.contains("Ing. de Sistemas Informaticos")]["MUJERES"])
        hombre.append(int(h_v))
        mujer.append(int(m_v))
        total.append(int(h_v + m_v))

    salvador_x_anho[column[3:]] = total

# %%
salvador_x_anho
# Out:
#                   2020  2021  2022  2023  2024
# Ing. Electrica      21    32    79    54    28
# Ing. Mecanica        9    14    36    31    11
# Ing. Industrial     53   145   167   101    33
# Ing. Informatica   100   217   137   161   114

# %%
max_y_slv = 230

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(11, 8))
fig.suptitle('Egresados por año en El Salvador de 2020 a 2024', fontsize=20)
axes = axes.flatten()

for i, carrera in enumerate(salvador_x_anho.index):
    slv_carrera = salvador_x_anho.loc[carrera]
    
    # Plotting
    axes[i].bar(salvador_x_anho.columns, slv_carrera, color="blue", label='Bar')
    
    axes[i].set_title(f'{carrera}')
    axes[i].set_xlabel("Año")
    axes[i].set_ylabel("Egresados")
    axes[i].set_ylim(0, max_y_slv)

plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Regresiones para egresados/año: lineal

# %%
max_y_mex = 1120

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(11, 8))
fig.suptitle('Egresados por año en México de 2018 a 2023 + predicción 2024 lineal', fontsize=20)
axes = axes.flatten()
mex_years = [yr for yr in range(2018, 2024)]

for i, carrera in enumerate(mexico_x_anho.index):
    # Cálculo de reg. lineal
    X = np.array(mex_years).reshape(-1, 1)
    y = np.array(mexico_x_anho.iloc[i]).reshape(-1, 1)
    reg = LinearRegression()
    reg.fit(X, y)
    
    mex_carrera = mexico_x_anho.loc[carrera]
    
    # Plotting
    axes[i].bar(mex_years, mex_carrera, color="green", label='Bar')
    
    X = np.array(mex_years+[2024]).reshape(-1, 1)
    axes[i].plot(mex_years+[2024], reg.predict(X), color="red", marker='|', linestyle='-', label='Line', lw=3)
    
    axes[i].set_title(f'{carrera} | Pred. 2024: {int(reg.predict(X)[-1][0])}')
    axes[i].set_xlabel("Año")
    axes[i].set_ylabel("Egresados")
    axes[i].set_ylim(0, max_y_mex)

plt.tight_layout()

# Show the plot
plt.show()

# %%
max_y_slv = 230

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(11, 8))
fig.suptitle('Egresados por año en El Salvador de 2020 a 2024 + predicción 2025 lineal', fontsize=20)
axes = axes.flatten()
slv_years = [yr for yr in range(2020, 2025)]

for i, carrera in enumerate(mexico_x_anho.index):
    # Cálculo de reg. lineal
    X = np.array(slv_years).reshape(-1, 1)
    y = np.array(salvador_x_anho.iloc[i]).reshape(-1, 1)
    reg = LinearRegression()
    reg.fit(X, y)
    
    slv_carrera = salvador_x_anho.loc[carrera]
    
    # Plotting
    axes[i].bar(slv_years, slv_carrera, color="blue", label='Bar')
    
    X = np.array(slv_years+[2025]).reshape(-1, 1)
    axes[i].plot(slv_years+[2025], reg.predict(X), color="red", marker='|', linestyle='-', label='Line', lw=3)
    
    axes[i].set_title(f'{carrera} | Pred. 2025: {int(reg.predict(X)[-1][0])}')
    axes[i].set_xlabel("Año")
    axes[i].set_ylabel("Egresados")
    axes[i].set_ylim(0, max_y_slv)

plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Regresiones para egresados/año: polinómica grado 2
# ## Nos dimos cuenta que reg. no define correctamente los datos

# %%
max_y_mex = 1120

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(11, 8))
fig.suptitle('Egresados por año en México de 2018 a 2023 + predicción 2024 polinómica', fontsize=20)
axes = axes.flatten()
mex_years = [yr for yr in range(2018, 2024)]


for i, carrera in enumerate(mexico_x_anho.index):
    # Cálculo de reg. lineal
    X = np.array(mex_years).reshape(-1, 1)
    y = np.array(mexico_x_anho.iloc[i]).reshape(-1, 1)
    poly_features= PolynomialFeatures(degree=2)
    X_poly = poly_features.fit_transform(X)
    reg = LinearRegression()
    reg.fit(X_poly, y)
    
    mex_carrera = mexico_x_anho.loc[carrera]
    
    # Plotting
    axes[i].bar(mex_years, mex_carrera, color="green", label='Bar')
    
    X = np.array(mex_years+[2024]).reshape(-1, 1)
    X_poly = poly_features.fit_transform(X)
    axes[i].plot(mex_years+[2024], reg.predict(X_poly), color="red", marker='|', linestyle='-', label='Line', lw=3)
    
    axes[i].set_title(f'{carrera} | Pred. 2024: {int(reg.predict(X_poly)[-1][0])}')
    axes[i].set_xlabel("Año")
    axes[i].set_ylabel("Egresados")
    axes[i].set_ylim(0, max_y_mex)

plt.tight_layout()

# Show the plot
plt.show()

# %%
max_y_slv = 230

# grid 2x2
fig, axes = plt.subplots(2, 2, figsize=(11, 8))
fig.suptitle('Egresados por año en El Salvador de 2020 a 2024 + predicción 2025 polinómica', fontsize=20)
axes = axes.flatten()
slv_years = [yr for yr in range(2020, 2025)]

for i, carrera in enumerate(mexico_x_anho.index):
    # Cálculo de reg. lineal
    X = np.array(slv_years).reshape(-1, 1)
    y = np.array(salvador_x_anho.iloc[i]).reshape(-1, 1)
    poly_features= PolynomialFeatures(degree=2)
    X_poly = poly_features.fit_transform(X)
    reg = LinearRegression()
    reg.fit(X_poly, y)
    
    slv_carrera = salvador_x_anho.loc[carrera]
    
    # Plotting
    axes[i].bar(slv_years, slv_carrera, color="blue", label='Bar')
    
    X = np.array(slv_years+[2025]).reshape(-1, 1)
    X_poly = poly_features.fit_transform(X)
    axes[i].plot(slv_years+[2025], reg.predict(X_poly), color="red", marker='|', linestyle='-', label='Line', lw=3)
    
    axes[i].set_title(f'{carrera} | Pred. 2025: {int(reg.predict(X_poly)[-1][0])}')
    axes[i].set_xlabel("Año")
    axes[i].set_ylabel("Egresados")
    axes[i].set_ylim(0, max_y_slv)

plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Es de notar que los datos aún no se ajustan correctamente, sin embargo, el paso necesario a partir de aquí sería obtener una mayor cantidad de datos (más años tabulados) para mejorar la investigación
